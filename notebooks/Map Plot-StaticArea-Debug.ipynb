# %%
import os
import pandas as pd
from math import ceil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML
import datetime
#pd.show_versions(as_json=False)

threshold = 1000

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
import matplotlib.pyplot as plt


#reader = shpreader.Reader('../other3p/county/countyl010g.shp')
reader = shpreader.Reader('../other3p/uscounties/uscounties.shp')

county_records = list(reader.records())
counties = [r.geometry for r in county_records]

COUNTIES = cfeature.ShapelyFeature(counties, ccrs.PlateCarree())

plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND.with_scale('50m'))
ax.add_feature(cfeature.OCEAN.with_scale('50m'))
ax.add_feature(cfeature.LAKES.with_scale('50m'))
ax.add_feature(COUNTIES, facecolor='none', edgecolor='gray')

ax.coastlines('50m')

ax.set_extent([-83, -65, 33, 44])
plt.show()

# %%
for c in county_records:
    print(c.attributes)
# Out:
# {'NAME': 'Lake of the Woods', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '077', 'FIPS': '27077'}
# {'NAME': 'Ferry', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '019', 'FIPS': '53019'}
# {'NAME': 'Stevens', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '065', 'FIPS': '53065'}
# {'NAME': 'Okanogan', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '047', 'FIPS': '53047'}
# {'NAME': 'Pend Oreille', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '051', 'FIPS': '53051'}
# {'NAME': 'Boundary', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '021', 'FIPS': '16021'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '053', 'FIPS': '30053'}
# {'NAME': 'Flathead', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '029', 'FIPS': '30029'}
# {'NAME': 'Glacier', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '035', 'FIPS': '30035'}
# {'NAME': 'Toole', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '101', 'FIPS': '30101'}
# {'NAME': 'Liberty', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '051', 'FIPS': '30051'}
# {'NAME': 'Hill', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '041', 'FIPS': '30041'}
# {'NAME': 'Sheridan', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '091', 'FIPS': '30091'}
# {'NAME': 'Divide', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '023', 'FIPS': '38023'}
# {'NAME': 'Burke', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '013', 'FIPS': '38013'}
# {'NAME': 'Renville', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '075', 'FIPS': '38075'}
# {'NAME': 'Bottineau', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '009', 'FIPS': '38009'}
# {'NAME': 'Rolette', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '079', 'FIPS': '38079'}
# {'NAME': 'Towner', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '095', 'FIPS': '38095'}
# {'NAME': 'Cavalier', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '019', 'FIPS': '38019'}
# {'NAME': 'Pembina', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '067', 'FIPS': '38067'}
# {'NAME': 'Kittson', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '069', 'FIPS': '27069'}
# {'NAME': 'Roseau', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '135', 'FIPS': '27135'}
# {'NAME': 'Blaine', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '005', 'FIPS': '30005'}
# {'NAME': 'Phillips', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '071', 'FIPS': '30071'}
# {'NAME': 'Valley', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '105', 'FIPS': '30105'}
# {'NAME': 'Daniels', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '019', 'FIPS': '30019'}
# {'NAME': 'Whatcom', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '073', 'FIPS': '53073'}
# {'NAME': 'Bonner', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '017', 'FIPS': '16017'}
# {'NAME': 'Ward', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '101', 'FIPS': '38101'}
# {'NAME': 'Koochiching', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '071', 'FIPS': '27071'}
# {'NAME': 'Skagit', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '057', 'FIPS': '53057'}
# {'NAME': 'Williams', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '105', 'FIPS': '38105'}
# {'NAME': 'McHenry', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '049', 'FIPS': '38049'}
# {'NAME': 'St. Louis', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '137', 'FIPS': '27137'}
# {'NAME': 'San Juan', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '055', 'FIPS': '53055'}
# {'NAME': 'Roosevelt', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '085', 'FIPS': '30085'}
# {'NAME': 'Mountrail', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '061', 'FIPS': '38061'}
# {'NAME': 'Marshall', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '089', 'FIPS': '27089'}
# {'NAME': 'Ramsey', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '071', 'FIPS': '38071'}
# {'NAME': 'Walsh', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '099', 'FIPS': '38099'}
# {'NAME': 'Beltrami', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '007', 'FIPS': '27007'}
# {'NAME': 'Pierce', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '069', 'FIPS': '38069'}
# {'NAME': 'Chelan', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '007', 'FIPS': '53007'}
# {'NAME': 'Pondera', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '073', 'FIPS': '30073'}
# {'NAME': 'Clallam', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '009', 'FIPS': '53009'}
# {'NAME': 'Benson', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '005', 'FIPS': '38005'}
# {'NAME': 'Chouteau', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '015', 'FIPS': '30015'}
# {'NAME': 'Snohomish', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '061', 'FIPS': '53061'}
# {'NAME': 'Island', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '029', 'FIPS': '53029'}
# {'NAME': 'Sanders', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '089', 'FIPS': '30089'}
# {'NAME': 'Lake', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '075', 'FIPS': '27075'}
# {'NAME': 'Nelson', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '063', 'FIPS': '38063'}
# {'NAME': 'Grand Forks', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '035', 'FIPS': '38035'}
# {'NAME': 'Polk', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '119', 'FIPS': '27119'}
# {'NAME': 'Pennington', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '113', 'FIPS': '27113'}
# {'NAME': 'Douglas', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '017', 'FIPS': '53017'}
# {'NAME': 'McKenzie', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '053', 'FIPS': '38053'}
# {'NAME': 'Jefferson', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '031', 'FIPS': '53031'}
# {'NAME': 'Richland', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '083', 'FIPS': '30083'}
# {'NAME': 'Teton', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '099', 'FIPS': '30099'}
# {'NAME': 'McCone', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '055', 'FIPS': '30055'}
# {'NAME': 'Shoshone', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '079', 'FIPS': '16079'}
# {'NAME': 'Spokane', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '063', 'FIPS': '53063'}
# {'NAME': 'Lake', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '047', 'FIPS': '30047'}
# {'NAME': 'Clearwater', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '029', 'FIPS': '27029'}
# {'NAME': 'Kootenai', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '055', 'FIPS': '16055'}
# {'NAME': 'Garfield', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '033', 'FIPS': '30033'}
# {'NAME': 'Red Lake', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '125', 'FIPS': '27125'}
# {'NAME': 'Grant', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '025', 'FIPS': '53025'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '043', 'FIPS': '53043'}
# {'NAME': 'Lewis and Clark', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '049', 'FIPS': '30049'}
# {'NAME': 'Kitsap', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '035', 'FIPS': '53035'}
# {'NAME': 'Itasca', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '061', 'FIPS': '27061'}
# {'NAME': 'Sheridan', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '083', 'FIPS': '38083'}
# {'NAME': 'Wells', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '103', 'FIPS': '38103'}
# {'NAME': 'McLean', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '055', 'FIPS': '38055'}
# {'NAME': 'Eddy', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '027', 'FIPS': '38027'}
# {'NAME': 'Dunn', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '025', 'FIPS': '38025'}
# {'NAME': 'Fergus', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '027', 'FIPS': '30027'}
# {'NAME': 'Dawson', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '021', 'FIPS': '30021'}
# {'NAME': 'King', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '033', 'FIPS': '53033'}
# {'NAME': 'Cascade', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '013', 'FIPS': '30013'}
# {'NAME': 'Griggs', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '039', 'FIPS': '38039'}
# {'NAME': 'Steele', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '091', 'FIPS': '38091'}
# {'NAME': 'Traill', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '097', 'FIPS': '38097'}
# {'NAME': 'Mason', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '045', 'FIPS': '53045'}
# {'NAME': 'Missoula', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '063', 'FIPS': '30063'}
# {'NAME': 'Petroleum', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '069', 'FIPS': '30069'}
# {'NAME': 'Powell', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '077', 'FIPS': '30077'}
# {'NAME': 'Kittitas', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '037', 'FIPS': '53037'}
# {'NAME': 'Foster', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '031', 'FIPS': '38031'}
# {'NAME': 'Mercer', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '057', 'FIPS': '38057'}
# {'NAME': 'Grays Harbor', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '027', 'FIPS': '53027'}
# {'NAME': 'Norman', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '107', 'FIPS': '27107'}
# {'NAME': 'Mahnomen', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '087', 'FIPS': '27087'}
# {'NAME': 'Mineral', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '061', 'FIPS': '30061'}
# {'NAME': 'Cass', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '021', 'FIPS': '27021'}
# {'NAME': 'Aroostook', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '003', 'FIPS': '23003'}
# {'NAME': 'Judith Basin', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '045', 'FIPS': '30045'}
# {'NAME': 'Hubbard', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '057', 'FIPS': '27057'}
# {'NAME': 'Benewah', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '009', 'FIPS': '16009'}
# {'NAME': 'Wibaux', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '109', 'FIPS': '30109'}
# {'NAME': 'Golden Valley', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '033', 'FIPS': '38033'}
# {'NAME': 'Billings', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '007', 'FIPS': '38007'}
# {'NAME': 'Stutsman', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '093', 'FIPS': '38093'}
# {'NAME': 'Kidder', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '043', 'FIPS': '38043'}
# {'NAME': 'Burleigh', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '015', 'FIPS': '38015'}
# {'NAME': 'Pierce', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '053', 'FIPS': '53053'}
# {'NAME': 'Oliver', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '065', 'FIPS': '38065'}
# {'NAME': 'Adams', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '001', 'FIPS': '53001'}
# {'NAME': 'Whitman', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '075', 'FIPS': '53075'}
# {'NAME': 'Barnes', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '003', 'FIPS': '38003'}
# {'NAME': 'Cass', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '017', 'FIPS': '38017'}
# {'NAME': 'Prairie', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '079', 'FIPS': '30079'}
# {'NAME': 'Becker', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '005', 'FIPS': '27005'}
# {'NAME': 'Clay', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '027', 'FIPS': '27027'}
# {'NAME': 'Thurston', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '067', 'FIPS': '53067'}
# {'NAME': 'Latah', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '057', 'FIPS': '16057'}
# {'NAME': 'Meagher', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '059', 'FIPS': '30059'}
# {'NAME': 'Yakima', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '077', 'FIPS': '53077'}
# {'NAME': 'Aitkin', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '001', 'FIPS': '27001'}
# {'NAME': 'Stark', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '089', 'FIPS': '38089'}
# {'NAME': 'Morton', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '059', 'FIPS': '38059'}
# {'NAME': 'Bayfield', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '007', 'FIPS': '55007'}
# {'NAME': 'Clearwater', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '035', 'FIPS': '16035'}
# {'NAME': 'Custer', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '017', 'FIPS': '30017'}
# {'NAME': 'Rosebud', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '087', 'FIPS': '30087'}
# {'NAME': 'Granite', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '039', 'FIPS': '30039'}
# {'NAME': 'Wadena', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '159', 'FIPS': '27159'}
# {'NAME': 'Crow Wing', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '035', 'FIPS': '27035'}
# {'NAME': 'Pacific', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '049', 'FIPS': '53049'}
# {'NAME': 'Lewis', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '041', 'FIPS': '53041'}
# {'NAME': 'Broadwater', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '007', 'FIPS': '30007'}
# {'NAME': 'Carlton', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '017', 'FIPS': '27017'}
# {'NAME': 'Golden Valley', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '037', 'FIPS': '30037'}
# {'NAME': 'Douglas', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '031', 'FIPS': '55031'}
# {'NAME': 'Musselshell', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '065', 'FIPS': '30065'}
# {'NAME': 'Wheatland', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '107', 'FIPS': '30107'}
# {'NAME': 'Franklin', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '021', 'FIPS': '53021'}
# {'NAME': 'Benton', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '005', 'FIPS': '53005'}
# {'NAME': 'Grant', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '037', 'FIPS': '38037'}
# {'NAME': 'Otter Tail', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '111', 'FIPS': '27111'}
# {'NAME': 'Garfield', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '023', 'FIPS': '53023'}
# {'NAME': 'Fallon', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '025', 'FIPS': '30025'}
# {'NAME': 'Idaho', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '049', 'FIPS': '16049'}
# {'NAME': 'Ravalli', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '081', 'FIPS': '30081'}
# {'NAME': 'Ashland', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '003', 'FIPS': '55003'}
# {'NAME': 'Logan', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '047', 'FIPS': '38047'}
# {'NAME': 'Emmons', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '029', 'FIPS': '38029'}
# {'NAME': 'LaMoure', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '045', 'FIPS': '38045'}
# {'NAME': 'Slope', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '087', 'FIPS': '38087'}
# {'NAME': 'Hettinger', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '041', 'FIPS': '38041'}
# {'NAME': 'Ransom', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '073', 'FIPS': '38073'}
# {'NAME': 'Richland', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '077', 'FIPS': '38077'}
# {'NAME': 'Wilkin', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '167', 'FIPS': '27167'}
# {'NAME': 'Nez Perce', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '069', 'FIPS': '16069'}
# {'NAME': 'Columbia', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '013', 'FIPS': '53013'}
# {'NAME': 'Walla Walla', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '071', 'FIPS': '53071'}
# {'NAME': 'Iron', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '051', 'FIPS': '55051'}
# {'NAME': 'Somerset', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '025', 'FIPS': '23025'}
# {'NAME': 'Piscataquis', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '021', 'FIPS': '23021'}
# {'NAME': 'Jefferson', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '043', 'FIPS': '30043'}
# {'NAME': 'Yellowstone', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '111', 'FIPS': '30111'}
# {'NAME': 'Treasure', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '103', 'FIPS': '30103'}
# {'NAME': 'Lewis', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '061', 'FIPS': '16061'}
# {'NAME': 'Asotin', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '003', 'FIPS': '53003'}
# {'NAME': 'Sioux', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '085', 'FIPS': '38085'}
# {'NAME': 'Pine', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '115', 'FIPS': '27115'}
# {'NAME': 'Penobscot', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '019', 'FIPS': '23019'}
# {'NAME': 'Skamania', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '059', 'FIPS': '53059'}
# {'NAME': 'Cowlitz', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '015', 'FIPS': '53015'}
# {'NAME': 'Wahkiakum', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '069', 'FIPS': '53069'}
# {'NAME': 'Todd', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '153', 'FIPS': '27153'}
# {'NAME': 'Morrison', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '097', 'FIPS': '27097'}
# {'NAME': 'McIntosh', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '051', 'FIPS': '38051'}
# {'NAME': 'Dickey', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '021', 'FIPS': '38021'}
# {'NAME': 'Sargent', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '081', 'FIPS': '38081'}
# {'NAME': 'Bowman', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '011', 'FIPS': '38011'}
# {'NAME': 'Adams', 'STATE_NAME': 'North Dakota', 'STATE_FIPS': '38', 'CNTY_FIPS': '001', 'FIPS': '38001'}
# {'NAME': 'Deer Lodge', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '023', 'FIPS': '30023'}
# {'NAME': 'Mille Lacs', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '095', 'FIPS': '27095'}
# {'NAME': 'Clatsop', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '007', 'FIPS': '41007'}
# {'NAME': 'Sweet Grass', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '097', 'FIPS': '30097'}
# {'NAME': 'Gallatin', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '031', 'FIPS': '30031'}
# {'NAME': 'Park', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '067', 'FIPS': '30067'}
# {'NAME': 'Columbia', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '009', 'FIPS': '41009'}
# {'NAME': 'Silver Bow', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '093', 'FIPS': '30093'}
# {'NAME': 'Washburn', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '129', 'FIPS': '55129'}
# {'NAME': 'Sawyer', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '113', 'FIPS': '55113'}
# {'NAME': 'Burnett', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '013', 'FIPS': '55013'}
# {'NAME': 'Kanabec', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '065', 'FIPS': '27065'}
# {'NAME': 'Carter', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '011', 'FIPS': '30011'}
# {'NAME': 'Stillwater', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '095', 'FIPS': '30095'}
# {'NAME': 'Grant', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '051', 'FIPS': '27051'}
# {'NAME': 'Douglas', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '041', 'FIPS': '27041'}
# {'NAME': 'Clark', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '011', 'FIPS': '53011'}
# {'NAME': 'Klickitat', 'STATE_NAME': 'Washington', 'STATE_FIPS': '53', 'CNTY_FIPS': '039', 'FIPS': '53039'}
# {'NAME': 'Big Horn', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '003', 'FIPS': '30003'}
# {'NAME': 'Traverse', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '155', 'FIPS': '27155'}
# {'NAME': 'Umatilla', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '059', 'FIPS': '41059'}
# {'NAME': 'Wallowa', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '063', 'FIPS': '41063'}
# {'NAME': 'Price', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '099', 'FIPS': '55099'}
# {'NAME': 'Campbell', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '021', 'FIPS': '46021'}
# {'NAME': 'Harding', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '063', 'FIPS': '46063'}
# {'NAME': 'McPherson', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '089', 'FIPS': '46089'}
# {'NAME': 'Perkins', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '105', 'FIPS': '46105'}
# {'NAME': 'Corson', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '031', 'FIPS': '46031'}
# {'NAME': 'Brown', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '013', 'FIPS': '46013'}
# {'NAME': 'Beaverhead', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '001', 'FIPS': '30001'}
# {'NAME': 'Marshall', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '091', 'FIPS': '46091'}
# {'NAME': 'Roberts', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '109', 'FIPS': '46109'}
# {'NAME': 'Morrow', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '049', 'FIPS': '41049'}
# {'NAME': 'Union', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '061', 'FIPS': '41061'}
# {'NAME': 'Madison', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '057', 'FIPS': '30057'}
# {'NAME': 'Benton', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '009', 'FIPS': '27009'}
# {'NAME': 'Gilliam', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '021', 'FIPS': '41021'}
# {'NAME': 'Powder River', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '075', 'FIPS': '30075'}
# {'NAME': 'Stearns', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '145', 'FIPS': '27145'}
# {'NAME': 'Tillamook', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '057', 'FIPS': '41057'}
# {'NAME': 'Washington', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '067', 'FIPS': '41067'}
# {'NAME': 'Pope', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '121', 'FIPS': '27121'}
# {'NAME': 'Stevens', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '149', 'FIPS': '27149'}
# {'NAME': 'Isanti', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '059', 'FIPS': '27059'}
# {'NAME': 'Chisago', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '025', 'FIPS': '27025'}
# {'NAME': 'Sherman', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '055', 'FIPS': '41055'}
# {'NAME': 'Polk', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '095', 'FIPS': '55095'}
# {'NAME': 'Multnomah', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '051', 'FIPS': '41051'}
# {'NAME': 'Hood River', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '027', 'FIPS': '41027'}
# {'NAME': 'Wasco', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '065', 'FIPS': '41065'}
# {'NAME': 'Lemhi', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '059', 'FIPS': '16059'}
# {'NAME': 'Washington', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '029', 'FIPS': '23029'}
# {'NAME': 'Franklin', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '007', 'FIPS': '23007'}
# {'NAME': 'Barron', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '005', 'FIPS': '55005'}
# {'NAME': 'Rusk', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '107', 'FIPS': '55107'}
# {'NAME': 'Carbon', 'STATE_NAME': 'Montana', 'STATE_FIPS': '30', 'CNTY_FIPS': '009', 'FIPS': '30009'}
# {'NAME': 'Walworth', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '129', 'FIPS': '46129'}
# {'NAME': 'Edmunds', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '045', 'FIPS': '46045'}
# {'NAME': 'Day', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '037', 'FIPS': '46037'}
# {'NAME': 'Big Stone', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '011', 'FIPS': '27011'}
# {'NAME': 'Sherburne', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '141', 'FIPS': '27141'}
# {'NAME': 'Ziebach', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '137', 'FIPS': '46137'}
# {'NAME': 'Dewey', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '041', 'FIPS': '46041'}
# {'NAME': 'Clackamas', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '005', 'FIPS': '41005'}
# {'NAME': 'Wright', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '171', 'FIPS': '27171'}
# {'NAME': 'Yamhill', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '071', 'FIPS': '41071'}
# {'NAME': 'Anoka', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '003', 'FIPS': '27003'}
# {'NAME': 'Kandiyohi', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '067', 'FIPS': '27067'}
# {'NAME': 'Swift', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '151', 'FIPS': '27151'}
# {'NAME': 'Taylor', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '119', 'FIPS': '55119'}
# {'NAME': 'Oxford', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '017', 'FIPS': '23017'}
# {'NAME': 'Grant', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '051', 'FIPS': '46051'}
# {'NAME': 'Meeker', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '093', 'FIPS': '27093'}
# {'NAME': 'Coos', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '007', 'FIPS': '33007'}
# {'NAME': 'Washington', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '163', 'FIPS': '27163'}
# {'NAME': 'Chippewa', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '017', 'FIPS': '55017'}
# {'NAME': 'Marion', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '047', 'FIPS': '41047'}
# {'NAME': 'Lac qui Parle', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '073', 'FIPS': '27073'}
# {'NAME': 'Adams', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '003', 'FIPS': '16003'}
# {'NAME': 'Potter', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '107', 'FIPS': '46107'}
# {'NAME': 'Faulk', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '049', 'FIPS': '46049'}
# {'NAME': 'Hennepin', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '053', 'FIPS': '27053'}
# {'NAME': 'Spink', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '115', 'FIPS': '46115'}
# {'NAME': 'St. Croix', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '109', 'FIPS': '55109'}
# {'NAME': 'Dunn', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '033', 'FIPS': '55033'}
# {'NAME': 'Butte', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '019', 'FIPS': '46019'}
# {'NAME': 'Valley', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '085', 'FIPS': '16085'}
# {'NAME': 'Clark', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '025', 'FIPS': '46025'}
# {'NAME': 'Codington', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '029', 'FIPS': '46029'}
# {'NAME': 'Chippewa', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '023', 'FIPS': '27023'}
# {'NAME': 'Ramsey', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '123', 'FIPS': '27123'}
# {'NAME': 'Baker', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '001', 'FIPS': '41001'}
# {'NAME': 'Polk', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '053', 'FIPS': '41053'}
# {'NAME': 'Wheeler', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '069', 'FIPS': '41069'}
# {'NAME': 'Meade', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '093', 'FIPS': '46093'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '041', 'FIPS': '41041'}
# {'NAME': 'Clark', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '019', 'FIPS': '55019'}
# {'NAME': 'Essex', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '009', 'FIPS': '50009'}
# {'NAME': 'Grand Isle', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '013', 'FIPS': '50013'}
# {'NAME': 'Franklin', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '011', 'FIPS': '50011'}
# {'NAME': 'Orleans', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '019', 'FIPS': '50019'}
# {'NAME': 'Clinton', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '019', 'FIPS': '36019'}
# {'NAME': 'Park', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '029', 'FIPS': '56029'}
# {'NAME': 'Crook', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '011', 'FIPS': '56011'}
# {'NAME': 'Big Horn', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '003', 'FIPS': '56003'}
# {'NAME': 'Campbell', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '005', 'FIPS': '56005'}
# {'NAME': 'Sheridan', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '033', 'FIPS': '56033'}
# {'NAME': 'Franklin', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '033', 'FIPS': '36033'}
# {'NAME': 'Grant', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '023', 'FIPS': '41023'}
# {'NAME': 'McLeod', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '085', 'FIPS': '27085'}
# {'NAME': 'Carver', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '019', 'FIPS': '27019'}
# {'NAME': 'Deuel', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '039', 'FIPS': '46039'}
# {'NAME': 'Dakota', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '037', 'FIPS': '27037'}
# {'NAME': 'Yellow Medicine', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '173', 'FIPS': '27173'}
# {'NAME': 'Sully', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '119', 'FIPS': '46119'}
# {'NAME': 'Hyde', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '069', 'FIPS': '46069'}
# {'NAME': 'Hand', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '059', 'FIPS': '46059'}
# {'NAME': 'Renville', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '129', 'FIPS': '27129'}
# {'NAME': 'Pierce', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '093', 'FIPS': '55093'}
# {'NAME': 'Custer', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '037', 'FIPS': '16037'}
# {'NAME': 'Eau Claire', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '035', 'FIPS': '55035'}
# {'NAME': 'Washington', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '087', 'FIPS': '16087'}
# {'NAME': 'Jefferson', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '031', 'FIPS': '41031'}
# {'NAME': 'Scott', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '139', 'FIPS': '27139'}
# {'NAME': 'Hamlin', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '057', 'FIPS': '46057'}
# {'NAME': 'Lamoille', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '015', 'FIPS': '50015'}
# {'NAME': 'Linn', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '043', 'FIPS': '41043'}
# {'NAME': 'Stanley', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '117', 'FIPS': '46117'}
# {'NAME': 'Caledonia', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '005', 'FIPS': '50005'}
# {'NAME': 'Waldo', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '027', 'FIPS': '23027'}
# {'NAME': 'Haakon', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '055', 'FIPS': '46055'}
# {'NAME': 'Fremont', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '043', 'FIPS': '16043'}
# {'NAME': 'Sibley', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '143', 'FIPS': '27143'}
# {'NAME': 'Chittenden', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '007', 'FIPS': '50007'}
# {'NAME': 'Kennebec', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '011', 'FIPS': '23011'}
# {'NAME': 'Goodhue', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '049', 'FIPS': '27049'}
# {'NAME': 'Benton', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '003', 'FIPS': '41003'}
# {'NAME': 'Redwood', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '127', 'FIPS': '27127'}
# {'NAME': 'Wood', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '141', 'FIPS': '55141'}
# {'NAME': 'Pepin', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '091', 'FIPS': '55091'}
# {'NAME': 'Teton', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '039', 'FIPS': '56039'}
# {'NAME': 'Beadle', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '005', 'FIPS': '46005'}
# {'NAME': 'Lyon', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '083', 'FIPS': '27083'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '081', 'FIPS': '27081'}
# {'NAME': 'Lawrence', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '081', 'FIPS': '46081'}
# {'NAME': 'Buffalo', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '011', 'FIPS': '55011'}
# {'NAME': 'Trempealeau', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '121', 'FIPS': '55121'}
# {'NAME': 'Jackson', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '053', 'FIPS': '55053'}
# {'NAME': 'Clark', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '033', 'FIPS': '16033'}
# {'NAME': 'Crook', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '013', 'FIPS': '41013'}
# {'NAME': 'Johnson', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '019', 'FIPS': '56019'}
# {'NAME': 'Hughes', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '065', 'FIPS': '46065'}
# {'NAME': 'Essex', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '031', 'FIPS': '36031'}
# {'NAME': 'Le Sueur', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '079', 'FIPS': '27079'}
# {'NAME': 'Rice', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '131', 'FIPS': '27131'}
# {'NAME': 'Kingsbury', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '077', 'FIPS': '46077'}
# {'NAME': 'Brookings', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '011', 'FIPS': '46011'}
# {'NAME': 'Pennington', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '103', 'FIPS': '46103'}
# {'NAME': 'Gem', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '045', 'FIPS': '16045'}
# {'NAME': 'Brown', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '015', 'FIPS': '27015'}
# {'NAME': 'Washington', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '023', 'FIPS': '50023'}
# {'NAME': 'Androscoggin', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '001', 'FIPS': '23001'}
# {'NAME': 'Nicollet', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '103', 'FIPS': '27103'}
# {'NAME': 'Wabasha', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '157', 'FIPS': '27157'}
# {'NAME': 'Malheur', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '045', 'FIPS': '41045'}
# {'NAME': 'Hancock', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '009', 'FIPS': '23009'}
# {'NAME': 'Grafton', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '009', 'FIPS': '33009'}
# {'NAME': 'Deschutes', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '017', 'FIPS': '41017'}
# {'NAME': 'Knox', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '013', 'FIPS': '23013'}
# {'NAME': 'Boise', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '015', 'FIPS': '16015'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '015', 'FIPS': '23015'}
# {'NAME': 'Addison', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '001', 'FIPS': '50001'}
# {'NAME': 'Carroll', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '003', 'FIPS': '33003'}
# {'NAME': 'Lane', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '039', 'FIPS': '41039'}
# {'NAME': 'Blue Earth', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '013', 'FIPS': '27013'}
# {'NAME': 'Juneau', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '057', 'FIPS': '55057'}
# {'NAME': 'Butte', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '023', 'FIPS': '16023'}
# {'NAME': 'Lyman', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '085', 'FIPS': '46085'}
# {'NAME': 'Orange', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '017', 'FIPS': '50017'}
# {'NAME': 'Waseca', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '161', 'FIPS': '27161'}
# {'NAME': 'Buffalo', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '017', 'FIPS': '46017'}
# {'NAME': 'Jerauld', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '073', 'FIPS': '46073'}
# {'NAME': 'Moody', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '101', 'FIPS': '46101'}
# {'NAME': 'Pipestone', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '117', 'FIPS': '27117'}
# {'NAME': 'Dodge', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '039', 'FIPS': '27039'}
# {'NAME': 'Sanborn', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '111', 'FIPS': '46111'}
# {'NAME': 'Murray', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '101', 'FIPS': '27101'}
# {'NAME': 'Cottonwood', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '033', 'FIPS': '27033'}
# {'NAME': 'Steele', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '147', 'FIPS': '27147'}
# {'NAME': 'Olmsted', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '109', 'FIPS': '27109'}
# {'NAME': 'Miner', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '097', 'FIPS': '46097'}
# {'NAME': 'Lake', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '079', 'FIPS': '46079'}
# {'NAME': 'Winona', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '169', 'FIPS': '27169'}
# {'NAME': 'Weston', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '045', 'FIPS': '56045'}
# {'NAME': 'Jones', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '075', 'FIPS': '46075'}
# {'NAME': 'Cumberland', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '005', 'FIPS': '23005'}
# {'NAME': 'Washakie', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '043', 'FIPS': '56043'}
# {'NAME': 'Monroe', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '081', 'FIPS': '55081'}
# {'NAME': 'Payette', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '075', 'FIPS': '16075'}
# {'NAME': 'Hamilton', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '041', 'FIPS': '36041'}
# {'NAME': 'Watonwan', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '165', 'FIPS': '27165'}
# {'NAME': 'Herkimer', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '043', 'FIPS': '36043'}
# {'NAME': 'La Crosse', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '063', 'FIPS': '55063'}
# {'NAME': 'Elmore', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '039', 'FIPS': '16039'}
# {'NAME': 'Hot Springs', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '017', 'FIPS': '56017'}
# {'NAME': 'Jefferson', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '051', 'FIPS': '16051'}
# {'NAME': 'Harney', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '025', 'FIPS': '41025'}
# {'NAME': 'Sagadahoc', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '023', 'FIPS': '23023'}
# {'NAME': 'Fremont', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '013', 'FIPS': '56013'}
# {'NAME': 'Jackson', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '071', 'FIPS': '46071'}
# {'NAME': 'Blaine', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '013', 'FIPS': '16013'}
# {'NAME': 'Teton', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '081', 'FIPS': '16081'}
# {'NAME': 'Windsor', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '027', 'FIPS': '50027'}
# {'NAME': 'Douglas', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '019', 'FIPS': '41019'}
# {'NAME': 'Aurora', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '003', 'FIPS': '46003'}
# {'NAME': 'Brule', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '015', 'FIPS': '46015'}
# {'NAME': 'Madison', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '065', 'FIPS': '16065'}
# {'NAME': 'Canyon', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '027', 'FIPS': '16027'}
# {'NAME': 'Mellette', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '095', 'FIPS': '46095'}
# {'NAME': 'Camas', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '025', 'FIPS': '16025'}
# {'NAME': 'Custer', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '033', 'FIPS': '46033'}
# {'NAME': 'Rutland', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '021', 'FIPS': '50021'}
# {'NAME': 'Faribault', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '043', 'FIPS': '27043'}
# {'NAME': 'Minnehaha', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '099', 'FIPS': '46099'}
# {'NAME': 'Rock', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '133', 'FIPS': '27133'}
# {'NAME': 'Freeborn', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '047', 'FIPS': '27047'}
# {'NAME': 'Nobles', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '105', 'FIPS': '27105'}
# {'NAME': 'Jackson', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '063', 'FIPS': '27063'}
# {'NAME': 'Martin', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '091', 'FIPS': '27091'}
# {'NAME': 'Houston', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '055', 'FIPS': '27055'}
# {'NAME': 'Mower', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '099', 'FIPS': '27099'}
# {'NAME': 'Fillmore', 'STATE_NAME': 'Minnesota', 'STATE_FIPS': '27', 'CNTY_FIPS': '045', 'FIPS': '27045'}
# {'NAME': 'Davison', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '035', 'FIPS': '46035'}
# {'NAME': 'Hanson', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '061', 'FIPS': '46061'}
# {'NAME': 'McCook', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '087', 'FIPS': '46087'}
# {'NAME': 'York', 'STATE_NAME': 'Maine', 'STATE_FIPS': '23', 'CNTY_FIPS': '031', 'FIPS': '23031'}
# {'NAME': 'Washington', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '115', 'FIPS': '36115'}
# {'NAME': 'Ada', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '001', 'FIPS': '16001'}
# {'NAME': 'Warren', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '113', 'FIPS': '36113'}
# {'NAME': 'Tripp', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '123', 'FIPS': '46123'}
# {'NAME': 'Belknap', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '001', 'FIPS': '33001'}
# {'NAME': 'Vernon', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '123', 'FIPS': '55123'}
# {'NAME': 'Shannon', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '113', 'FIPS': '46113'}
# {'NAME': 'Owyhee', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '073', 'FIPS': '16073'}
# {'NAME': 'Bonneville', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '019', 'FIPS': '16019'}
# {'NAME': 'Bingham', 'STATE_NAME': 'Idaho', 'STATE_FIPS': '16', 'CNTY_FIPS': '011', 'FIPS': '16011'}
# {'NAME': 'Klamath', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '035', 'FIPS': '41035'}
# {'NAME': 'Lake', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '037', 'FIPS': '41037'}
# {'NAME': 'Coos', 'STATE_NAME': 'Oregon', 'STATE_FIPS': '41', 'CNTY_FIPS': '011', 'FIPS': '41011'}
# {'NAME': 'Merrimack', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '013', 'FIPS': '33013'}
# {'NAME': 'Sullivan', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '019', 'FIPS': '33019'}
# {'NAME': 'Strafford', 'STATE_NAME': 'New Hampshire', 'STATE_FIPS': '33', 'CNTY_FIPS': '017', 'FIPS': '33017'}
# {'NAME': 'Richland', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '103', 'FIPS': '55103'}
# {'NAME': 'Natrona', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '025', 'FIPS': '56025'}
# {'NAME': 'Gregory', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '053', 'FIPS': '46053'}
# {'NAME': 'Niobrara', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '027', 'FIPS': '56027'}
# {'NAME': 'Charles Mix', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '023', 'FIPS': '46023'}
# {'NAME': 'Turner', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '125', 'FIPS': '46125'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '083', 'FIPS': '46083'}
# {'NAME': 'Worth', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '195', 'FIPS': '19195'}
# {'NAME': 'Mitchell', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '131', 'FIPS': '19131'}
# {'NAME': 'Allamakee', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '005', 'FIPS': '19005'}
# {'NAME': 'Winnebago', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '189', 'FIPS': '19189'}
# {'NAME': 'Winneshiek', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '191', 'FIPS': '19191'}
# {'NAME': 'Converse', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '009', 'FIPS': '56009'}
# {'NAME': 'Osceola', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '143', 'FIPS': '19143'}
# {'NAME': 'Dickinson', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '059', 'FIPS': '19059'}
# {'NAME': 'Kossuth', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '109', 'FIPS': '19109'}
# {'NAME': 'Howard', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '089', 'FIPS': '19089'}
# {'NAME': 'Emmet', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '063', 'FIPS': '19063'}
# {'NAME': 'Lyon', 'STATE_NAME': 'Iowa', 'STATE_FIPS': '19', 'CNTY_FIPS': '119', 'FIPS': '19119'}
# {'NAME': 'Douglas', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '043', 'FIPS': '46043'}
# {'NAME': 'Hutchinson', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '067', 'FIPS': '46067'}
# {'NAME': 'Fall River', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '047', 'FIPS': '46047'}
# {'NAME': 'Sublette', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '035', 'FIPS': '56035'}
# {'NAME': 'Crawford', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '023', 'FIPS': '55023'}
# {'NAME': 'Saratoga', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '091', 'FIPS': '36091'}
# {'NAME': 'Bennett', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '007', 'FIPS': '46007'}
# {'NAME': 'Todd', 'STATE_NAME': 'South Dakota', 'STATE_FIPS': '46', 'CNTY_FIPS': '121', 'FIPS': '46121'}
# {'NAME': 'Bennington', 'STATE_NAME': 'Vermont', 'STATE_FIPS': '50', 'CNTY_FIPS': '003', 'FIPS': '50003'}
# {'NAME': 'Lincoln', 'STATE_NAME': 'Wyoming', 'STATE_FIPS': '56', 'CNTY_FIPS': '023', 'FIPS': '56023'}
# {'NAME': 'Fulton', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '035', 'FIPS': '36035'}
# ...
# {'NAME': 'Lake', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '085', 'FIPS': '26085'}
# {'NAME': 'Osceola', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '133', 'FIPS': '26133'}
# {'NAME': 'Arenac', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '011', 'FIPS': '26011'}
# {'NAME': 'Clare', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '035', 'FIPS': '26035'}
# {'NAME': 'Gladwin', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '051', 'FIPS': '26051'}
# {'NAME': 'Huron', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '063', 'FIPS': '26063'}
# {'NAME': 'Bay', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '017', 'FIPS': '26017'}
# {'NAME': 'Marquette', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '077', 'FIPS': '55077'}
# {'NAME': 'Green Lake', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '047', 'FIPS': '55047'}
# {'NAME': 'Fond du Lac', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '039', 'FIPS': '55039'}
# {'NAME': 'Sheboygan', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '117', 'FIPS': '55117'}
# {'NAME': 'Midland', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '111', 'FIPS': '26111'}
# {'NAME': 'Oceana', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '127', 'FIPS': '26127'}
# {'NAME': 'Isabella', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '073', 'FIPS': '26073'}
# {'NAME': 'Newaygo', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '123', 'FIPS': '26123'}
# {'NAME': 'Mecosta', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '107', 'FIPS': '26107'}
# {'NAME': 'Tuscola', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '157', 'FIPS': '26157'}
# {'NAME': 'Oswego', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '075', 'FIPS': '36075'}
# {'NAME': 'Sanilac', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '151', 'FIPS': '26151'}
# {'NAME': 'Columbia', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '021', 'FIPS': '55021'}
# {'NAME': 'Sauk', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '111', 'FIPS': '55111'}
# {'NAME': 'Dodge', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '027', 'FIPS': '55027'}
# {'NAME': 'Oneida', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '065', 'FIPS': '36065'}
# {'NAME': 'Saginaw', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '145', 'FIPS': '26145'}
# {'NAME': 'Washington', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '131', 'FIPS': '55131'}
# {'NAME': 'Ozaukee', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '089', 'FIPS': '55089'}
# {'NAME': 'Muskegon', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '121', 'FIPS': '26121'}
# {'NAME': 'Montcalm', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '117', 'FIPS': '26117'}
# {'NAME': 'Gratiot', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '057', 'FIPS': '26057'}
# {'NAME': 'Cayuga', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '011', 'FIPS': '36011'}
# {'NAME': 'Niagara', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '063', 'FIPS': '36063'}
# {'NAME': 'Orleans', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '073', 'FIPS': '36073'}
# {'NAME': 'Monroe', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '055', 'FIPS': '36055'}
# {'NAME': 'Wayne', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '117', 'FIPS': '36117'}
# {'NAME': 'Lapeer', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '087', 'FIPS': '26087'}
# {'NAME': 'Kent', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '081', 'FIPS': '26081'}
# {'NAME': 'Dane', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '025', 'FIPS': '55025'}
# {'NAME': 'Onondaga', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '067', 'FIPS': '36067'}
# {'NAME': 'Genesee', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '049', 'FIPS': '26049'}
# {'NAME': 'Ottawa', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '139', 'FIPS': '26139'}
# {'NAME': 'Jefferson', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '055', 'FIPS': '55055'}
# {'NAME': 'Waukesha', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '133', 'FIPS': '55133'}
# {'NAME': 'Milwaukee', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '079', 'FIPS': '55079'}
# {'NAME': 'Madison', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '053', 'FIPS': '36053'}
# {'NAME': 'St. Clair', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '147', 'FIPS': '26147'}
# {'NAME': 'Shiawassee', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '155', 'FIPS': '26155'}
# {'NAME': 'Genesee', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '037', 'FIPS': '36037'}
# {'NAME': 'Ionia', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '067', 'FIPS': '26067'}
# {'NAME': 'Clinton', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '037', 'FIPS': '26037'}
# {'NAME': 'Erie', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '029', 'FIPS': '36029'}
# {'NAME': 'Ontario', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '069', 'FIPS': '36069'}
# {'NAME': 'Seneca', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '099', 'FIPS': '36099'}
# {'NAME': 'Livingston', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '051', 'FIPS': '36051'}
# {'NAME': 'Macomb', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '099', 'FIPS': '26099'}
# {'NAME': 'Oakland', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '125', 'FIPS': '26125'}
# {'NAME': 'Wyoming', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '121', 'FIPS': '36121'}
# {'NAME': 'Green', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '045', 'FIPS': '55045'}
# {'NAME': 'Rock', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '105', 'FIPS': '55105'}
# {'NAME': 'Walworth', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '127', 'FIPS': '55127'}
# {'NAME': 'Racine', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '101', 'FIPS': '55101'}
# {'NAME': 'Cortland', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '023', 'FIPS': '36023'}
# {'NAME': 'Livingston', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '093', 'FIPS': '26093'}
# {'NAME': 'Ingham', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '065', 'FIPS': '26065'}
# {'NAME': 'Allegan', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '005', 'FIPS': '26005'}
# {'NAME': 'Eaton', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '045', 'FIPS': '26045'}
# {'NAME': 'Barry', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '015', 'FIPS': '26015'}
# {'NAME': 'Yates', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '123', 'FIPS': '36123'}
# {'NAME': 'Chenango', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '017', 'FIPS': '36017'}
# {'NAME': 'Kenosha', 'STATE_NAME': 'Wisconsin', 'STATE_FIPS': '55', 'CNTY_FIPS': '059', 'FIPS': '55059'}
# {'NAME': 'Tompkins', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '109', 'FIPS': '36109'}
# {'NAME': 'Steuben', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '101', 'FIPS': '36101'}
# {'NAME': 'Chautauqua', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '013', 'FIPS': '36013'}
# {'NAME': 'Schuyler', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '097', 'FIPS': '36097'}
# {'NAME': 'Cattaraugus', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '009', 'FIPS': '36009'}
# {'NAME': 'Allegany', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '003', 'FIPS': '36003'}
# {'NAME': 'Stephenson', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '177', 'FIPS': '17177'}
# {'NAME': 'Winnebago', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '201', 'FIPS': '17201'}
# {'NAME': 'McHenry', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '111', 'FIPS': '17111'}
# {'NAME': 'Boone', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '007', 'FIPS': '17007'}
# {'NAME': 'Lake', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '097', 'FIPS': '17097'}
# {'NAME': 'Wayne', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '163', 'FIPS': '26163'}
# {'NAME': 'Washtenaw', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '161', 'FIPS': '26161'}
# {'NAME': 'Jackson', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '075', 'FIPS': '26075'}
# {'NAME': 'Kalamazoo', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '077', 'FIPS': '26077'}
# {'NAME': 'Calhoun', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '025', 'FIPS': '26025'}
# {'NAME': 'Van Buren', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '159', 'FIPS': '26159'}
# {'NAME': 'Broome', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '007', 'FIPS': '36007'}
# {'NAME': 'Tioga', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '107', 'FIPS': '36107'}
# {'NAME': 'Chemung', 'STATE_NAME': 'New York', 'STATE_FIPS': '36', 'CNTY_FIPS': '015', 'FIPS': '36015'}
# {'NAME': 'Erie', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '049', 'FIPS': '42049'}
# {'NAME': 'Berrien', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '021', 'FIPS': '26021'}
# {'NAME': 'Ogle', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '141', 'FIPS': '17141'}
# {'NAME': 'Carroll', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '015', 'FIPS': '17015'}
# {'NAME': 'Cook', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '031', 'FIPS': '17031'}
# {'NAME': 'Kane', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '089', 'FIPS': '17089'}
# {'NAME': 'DeKalb', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '037', 'FIPS': '17037'}
# {'NAME': 'Monroe', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '115', 'FIPS': '26115'}
# {'NAME': 'Lenawee', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '091', 'FIPS': '26091'}
# {'NAME': 'Hillsdale', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '059', 'FIPS': '26059'}
# {'NAME': 'Branch', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '023', 'FIPS': '26023'}
# {'NAME': 'St. Joseph', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '149', 'FIPS': '26149'}
# {'NAME': 'Cass', 'STATE_NAME': 'Michigan', 'STATE_FIPS': '26', 'CNTY_FIPS': '027', 'FIPS': '26027'}
# {'NAME': 'Bradford', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '015', 'FIPS': '42015'}
# {'NAME': 'Tioga', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '117', 'FIPS': '42117'}
# {'NAME': 'Warren', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '123', 'FIPS': '42123'}
# {'NAME': 'Susquehanna', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '115', 'FIPS': '42115'}
# {'NAME': 'McKean', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '083', 'FIPS': '42083'}
# {'NAME': 'Potter', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '105', 'FIPS': '42105'}
# {'NAME': 'DuPage', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '043', 'FIPS': '17043'}
# {'NAME': 'Ashtabula', 'STATE_NAME': 'Ohio', 'STATE_FIPS': '39', 'CNTY_FIPS': '007', 'FIPS': '39007'}
# {'NAME': 'Whiteside', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '195', 'FIPS': '17195'}
# {'NAME': 'Lee', 'STATE_NAME': 'Illinois', 'STATE_FIPS': '17', 'CNTY_FIPS': '103', 'FIPS': '17103'}
# {'NAME': 'Crawford', 'STATE_NAME': 'Pennsylvania', 'STATE_FIPS': '42', 'CNTY_FIPS': '039', 'FIPS': '42039'}
# {'NAME': 'Lake', 'STATE_NAME': 'Ohio', 'STATE_FIPS': '39', 'CNTY_FIPS': '085', 'FIPS': '39085'}
# {'NAME': 'LaPorte', 'STATE_NAME': 'Indiana', 'STATE_FIPS': '18', 'CNTY_FIPS': '091', 'FIPS': '18091'}
# {'NAME': 'St. Joseph', 'STATE_NAME': 'Indiana', 'STATE_FIPS': '18', 'CNTY_FIPS': '141', 'FIPS': '18141'}
# {'NAME': 'Elkhart', 'STATE_NAME': 'Indiana', 'STATE_FIPS': '18', 'CNTY_FIPS': '039', 'FIPS': '18039'}
# {'NAME': 'LaGrange', 'STATE_NAME': 'Indiana', 'STATE_FIPS': '18', 'CNTY_FIPS': '087', 'FIPS': '18087'}
# {'NAME': 'Steuben', 'STATE_NAME': 'Indiana', 'STATE_FIPS': '18', 'CNTY_FIPS': '151', 'FIPS': '18151'}
# {'NAME': 'North Slope', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '185', 'FIPS': '02185'}
# {'NAME': 'Northwest Arctic', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '188', 'FIPS': '02188'}
# {'NAME': 'Fairbanks North Star', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '090', 'FIPS': '02090'}
# {'NAME': 'Bristol Bay', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '060', 'FIPS': '02060'}
# {'NAME': 'Nome', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '180', 'FIPS': '02180'}
# {'NAME': 'Matanuska-Susitna', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '170', 'FIPS': '02170'}
# {'NAME': 'Wade Hampton', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '270', 'FIPS': '02270'}
# {'NAME': 'Bethel', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '050', 'FIPS': '02050'}
# {'NAME': 'Anchorage', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '020', 'FIPS': '02020'}
# {'NAME': 'Kenai Peninsula', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '122', 'FIPS': '02122'}
# {'NAME': 'Dillingham', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '070', 'FIPS': '02070'}
# {'NAME': 'Lake and Peninsula', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '164', 'FIPS': '02164'}
# {'NAME': 'Haines', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '100', 'FIPS': '02100'}
# {'NAME': 'Juneau', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '110', 'FIPS': '02110'}
# {'NAME': 'Kodiak Island', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '150', 'FIPS': '02150'}
# {'NAME': 'Sitka', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '220', 'FIPS': '02220'}
# {'NAME': 'Wrangell-Petersburg', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '280', 'FIPS': '02280'}
# {'NAME': 'Ketchikan Gateway', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '130', 'FIPS': '02130'}
# {'NAME': 'Prince of Wales-Outer Ketchikan', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '201', 'FIPS': '02201'}
# {'NAME': 'Aleutians East', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '013', 'FIPS': '02013'}
# {'NAME': 'Aleutians West', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '016', 'FIPS': '02016'}
# {'NAME': 'Kalawao', 'STATE_NAME': 'Hawaii', 'STATE_FIPS': '15', 'CNTY_FIPS': '005', 'FIPS': '15005'}
# {'NAME': 'Kauai', 'STATE_NAME': 'Hawaii', 'STATE_FIPS': '15', 'CNTY_FIPS': '007', 'FIPS': '15007'}
# {'NAME': 'Honolulu', 'STATE_NAME': 'Hawaii', 'STATE_FIPS': '15', 'CNTY_FIPS': '003', 'FIPS': '15003'}
# {'NAME': 'Maui', 'STATE_NAME': 'Hawaii', 'STATE_FIPS': '15', 'CNTY_FIPS': '009', 'FIPS': '15009'}
# {'NAME': 'Hawaii', 'STATE_NAME': 'Hawaii', 'STATE_FIPS': '15', 'CNTY_FIPS': '001', 'FIPS': '15001'}
# {'NAME': 'Pittsylvania', 'STATE_NAME': 'Virginia', 'STATE_FIPS': '51', 'CNTY_FIPS': '143', 'FIPS': '51143'}
# {'NAME': 'Danville', 'STATE_NAME': 'Virginia', 'STATE_FIPS': '51', 'CNTY_FIPS': '590', 'FIPS': '51590'}
# {'NAME': 'Valdez-Cordova', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '261', 'FIPS': '02261'}
# {'NAME': 'Yakutat', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '282', 'FIPS': '02282'}
# {'NAME': 'Skagway-Hoonah-Angoon', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '232', 'FIPS': '02232'}
# {'NAME': 'Yukon-Koyukuk', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '290', 'FIPS': '02290'}
# {'NAME': 'Southeast Fairbanks', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '240', 'FIPS': '02240'}
# {'NAME': 'Denali', 'STATE_NAME': 'Alaska', 'STATE_FIPS': '02', 'CNTY_FIPS': '068', 'FIPS': '02068'}
# {'NAME': 'Broomfield', 'STATE_NAME': 'Colorado', 'STATE_FIPS': '08', 'CNTY_FIPS': '014', 'FIPS': '08014'}

# %%
# Load Data
def load_raw(fn):
    datapath = os.path.join('../csse_covid_19_data/csse_covid_19_time_series/', fn)

    #datapath = '../csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
    
    raw = pd.read_csv(datapath)
    #del raw['Lat']
    #del raw['Long']
    #raw= raw.replace('Mainland China','China')
    raw = raw[raw.iso2=='US']
    raw = raw[pd.notnull(raw.UID) & ~(raw.Lat==0.0)]
    # fix HI/AK later
    raw = raw[~(raw.Province_State=='Alaska') & ~(raw.Province_State=='Hawaii')]
    return raw

raw = load_raw('time_series_covid19_confirmed_us.csv')
#raw_deaths = load_raw('time_series_covid19_deaths_global.csv')

raw
# Out:
#            UID iso2 iso3  code3    FIPS          Admin2 Province_State  \
# 5     84001001   US  USA    840  1001.0         Autauga        Alabama
# 6     84001003   US  USA    840  1003.0         Baldwin        Alabama
# 7     84001005   US  USA    840  1005.0         Barbour        Alabama
# 8     84001007   US  USA    840  1007.0            Bibb        Alabama
# 9     84001009   US  USA    840  1009.0          Blount        Alabama
# ...        ...  ...  ...    ...     ...             ...            ...
# 3256  84070016   US  USA    840     NaN    Central Utah           Utah
# 3257  84070017   US  USA    840     NaN  Southeast Utah           Utah
# 3258  84070018   US  USA    840     NaN  Southwest Utah           Utah
# 3259  84070019   US  USA    840     NaN       TriCounty           Utah
# 3260  84070020   US  USA    840     NaN    Weber-Morgan           Utah
#
#      Country_Region        Lat       Long_  ... 5/15/20  5/16/20  5/17/20  \
# 5                US  32.539527  -86.644082  ...     103      110      110
# 6                US  30.727750  -87.722071  ...     244      254      254
# 7                US  31.868263  -85.387129  ...      79       79       81
# 8                US  32.996421  -87.125115  ...      49       50       50
# 9                US  33.982109  -86.567906  ...      45       45       46
# ...             ...        ...         ...  ...     ...      ...      ...
# 3256             US  39.372319 -111.575868  ...      29       29       30
# 3257             US  38.996171 -110.701396  ...      13       14       14
# 3258             US  37.854472 -111.441876  ...     200      209      219
# 3259             US  40.124915 -109.517442  ...      16       19       19
# 3260             US  41.271160 -111.914512  ...     216      221      226
#
#       5/18/20  5/19/20  5/20/20  5/21/20  5/22/20  5/23/20  5/24/20
# 5         120      127      136      143      149      155      159
# 6         260      262      270      269      271      273      274
# 7          85       90       96       99      104      105      110
# 8          50       51       52       52       55       58       59
# 9          47       47       47       47       49       49       49
# ...       ...      ...      ...      ...      ...      ...      ...
# 3256       30       30       31       32       34       33       33
# 3257       15       16       16       17       18       18       20
# 3258      236      245      260      271      281      294      305
# 3259       22       19       20       20       21       20       20
# 3260      234      234      242      251      252      256      260
#
# [3116 rows x 135 columns]

# %%
#%%capture
# %matplotlib inline
from math import log
plt.rcParams["figure.figsize"] = [10, 5]
x=raw['Long_']
y=raw['Lat']
#c=raw['4/19/20'].apply(lambda x: log(x) if x>0 else 0)
weeks = 12
window = 7
dates=raw.columns[-weeks*7:]
#print(dates)
new = [(raw[dates[i]]-raw[dates[i-window]]).apply(lambda x: log(x) if x>0 else 0) for i in range(window,len(dates))]
maxval=max([c.max() for c in new])
fips = raw['FIPS'].fillna(-1).apply(lambda x: int(x))

#print(c.min(),c.max())
plt.gca().set_aspect('equal', adjustable='box')
fig, ax = plt.subplots()

#plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-83, -65, 33, 44])

cty_fips = set([int(r.attributes['FIPS']) for r in county_records])
raw_fips = set(fips)

print(cty_fips.difference(raw_fips))
print(raw_fips.difference(cty_fips))

print(list(sorted(cty_fips))[:10])
print(list(sorted(raw_fips))[:10])

#plt.show()
lookup_0 = dict(zip(list(fips),list(raw['Admin2'])))
test_mapping = zip([r.attributes['NAME'] for r in county_records], [lookup_0[int(r.attributes['FIPS'])] if int(r.attributes['FIPS']) in lookup_0 else 'missing' for r in county_records])
#for (r,l) in test_mapping:
#    print(r,l)

cmap=plt.cm.autumn_r
#norm=plt.Normalize(min(mapping),max(mapping))
norm=plt.Normalize(0,maxval)
norm_lat = plt.Normalize(min(y),max(y))
from math import exp

def plot_map(date_tuple):
    c,dt = date_tuple
    # todo: this could be done outside the call.
    #print(len(fips),len(c))
    lookup = dict(zip(list(fips),c))
    #print(lookup)
    mapping = [lookup[int(r.attributes['FIPS'])] if int(r.attributes['FIPS']) in lookup else 0.0 for r in county_records]
    lookup_lat = dict(zip(list(fips),x))
    mapping_lat = [lookup_lat[int(r.attributes['FIPS'])] if int(r.attributes['FIPS']) in lookup_lat else 0.0 for r in county_records]
    print(exp(lookup[53033]))
    #print(mapping)
    #print(min(mapping),max(mapping))
    #print(len(mapping),len(COUNTIES))
    #print(dt)
    ax.clear()
    ax.add_feature(cfeature.LAND.with_scale('50m'))
    ax.add_feature(cfeature.OCEAN.with_scale('50m'))
    ax.add_feature(cfeature.LAKES.with_scale('50m'))
    print(max(mapping),cmap(norm(max(mapping))))
    #add_feature(COUNTIES
    ax.add_geometries(counties, ccrs.PlateCarree(), 
                      #facecolor=list(cmap(norm(mapping))), 
                      facecolor=list(cmap(norm_lat(mapping_lat))),
                      edgecolor='gray', linewidth=0.1)
    ax.coastlines('50m')

    #ax.scatter(x,y, c=c, alpha=0.5, cmap='autumn_r')
    ax.set_yticks([])
    ax.set_xticks([])
    #ax.set_extent([-76,-72,38,42]) Manhattan
    #ax.set_extent([-83, -65, 33, 44]) Eastern Seaboard
    #ax.set_extent([-124,-120,46,49])
    ax.set_extent([-130,-62,20,50]) # Cont. US
    plt.box(False)
    ax.text(0.95, 0.15, dt, transform=ax.transAxes, color='#222222', size=24, ha='right', weight=800)

frames = list(zip(new,dates[window:]))
plot_map(frames[-1])
#animator = animation.FuncAnimation(fig, plot_map, frames=frames, repeat=False)
#HTML(animator.to_jshtml()) 

#maxDate=raw.columns[-1].replace('/','-')
#animator.save('data/animation-fill-{}.gif'.format(maxDate))
#animator.save('data/animation-fill-latest.gif')
# Out:
# {2050, 2180, 2185, 2060, 2188, 2068, 2070, 2201, 15001, 15003, 15005, 15007, 46113, 15009, 2090, 2220, 2100, 2232, 51515, 2110, 2240, 2122, 2130, 2261, 2013, 2270, 2016, 2020, 2150, 2280, 2282, 2290, 2164, 2170}
# {46102, -1}
# [1001, 1003, 1005, 1007, 1009, 1011, 1013, 1015, 1017, 1019]
# [-1, 1001, 1003, 1005, 1007, 1009, 1011, 1013, 1015, 1017]
# 310.99999999999994
# 9.189321004752108 (1.0, 0.12549019607843137, 0.0, 1.0)

# %%
#fips
